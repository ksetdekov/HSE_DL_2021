# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://github.com/NktBkzn/HSE_DL_2021/blob/master/12_week/RNN_formulas_explained.ipynb)

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %cd /content/gdrive/My Drive/HSE_DL_2021/12_week
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/HSE_DL_2021/12_week

# %% [markdown]
# ## RNN formulas
#
# В этом ноутбуке приведены формулы для проведения forward и backward pass в RNN

# %%
from IPython import display
display.Image('images/rnn1.png', retina=True)

# %% [markdown]
#  ### Forward pass

# %% [markdown]
#  ### Backward pass
